# %%
from bs4 import BeautifulSoup
import requests

# %%
BASE_URL = 'https://yankee.org/tournaments'

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text, 'html')

# %%
#print(soup)

# %%
# Scraper function
def scrape_tournaments():
    response = requests.get(BASE_URL)
    response.raise_for_status()  # Raise an error if the request fails
    #soup = BeautifulSoup(response.text, "html.parser")

    # Find the tournament table
    table = soup.find("table", class_="tournamentList")

    # Initialize a list to store tournament data
    tournaments = []

    # Iterate through each row in the table body
    for row in table.find("tbody").find_all("tr"):
        try:
            # Extract data from each cell
            date = row.find("td").text.strip()
            name = row.find("td").find_next("td").text.strip()
            link = row.find("td").find_next("td").find("a")["href"]
            location = row.find("td").find_next("td").find_next("td").text.strip()
            type_ = row.find("td").find_next("td").find_next("td").find_next("td").text.strip()
            level = row.find("td").find_next("td").find_next("td").find_next("td").find_next("td").text.strip()
            cost = row.find("td").find_next("td").find_next("td").find_next("td").find_next("td").find_next("td").find_next("td").text.strip()
            max_teams = row.find("td").find_next("td").find_next("td").find_next("td").find_next("td").find_next("td").find_next("td").find_next("td").text.strip()
            confirmed = row.find("td").find_next("td").find_next("td").find_next("td").find_next("td").find_next("td").find_next("td").find_next("td").find_next("td").text.strip()
            status = row.find("td").find_next("td").find_next("td").find_next("td").find_next("td").find_next("td").find_next("td").find_next("td").find_next("td").find_next("td").text.strip()

            # Append the extracted data as a dictionary
            tournaments.append({
                "date": date,
                "name": name,
                "link": link,
                "location": location,
                "type": type_,
                "level": level,
                "cost": cost,
                "max_teams": max_teams,
                "confirmed": confirmed,
                "status": status
            })
        except AttributeError:
            # Skip rows with missing data
            continue

    return tournaments

# Test the scraper
if __name__ == "__main__":
    data = scrape_tournaments()
    for tournament in data:
        print(tournament)
# Out:
# {'date': '12/22/24', 'name': 'W B(Flat) 12/22/2024', 'link': '/tournaments/w-bflat-12-22-2024', 'location': 'NECC', 'type': 'W', 'level': 'B', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '12/22/24', 'name': 'RCO C 12/22/2024', 'link': '/tournaments/rco-c-12-22-2024', 'location': 'STW', 'type': 'RCO', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$198', 'confirmed': 'Michelle Grambley', 'status': '10'}
# {'date': '12/22/24', 'name': 'M B- 12/22/2024', 'link': '/tournaments/m-b-12-22-2024', 'location': 'NECC', 'type': 'M', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '10'}
# {'date': '12/22/24', 'name': 'W C+ 12/22/2024', 'link': '/tournaments/w-c-12-22-2024', 'location': 'BRU', 'type': 'W', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$210', 'confirmed': 'Mark Robarts', 'status': '10'}
# {'date': '12/22/24', 'name': 'M C+ 12/22/2024', 'link': '/tournaments/m-c-12-22-2024', 'location': 'BRU', 'type': 'M', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$210', 'confirmed': 'Mark Robarts', 'status': '10'}
# {'date': '12/24/24', 'name': 'RCO C(Flat) 12/24/2024', 'link': '/tournaments/rco-cflat-12-24-2024', 'location': 'SLAM', 'type': 'RCO', 'level': 'C', 'cost': '8:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '4'}
# {'date': '12/24/24', 'name': 'RCO B-(Flat) 12/24/2024', 'link': '/tournaments/rco-b-flat-12-24-2024', 'location': 'SLAM', 'type': 'RCO', 'level': 'B-', 'cost': '8:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '4'}
# {'date': '12/27/24', 'name': 'RCO C- 12/27/2024', 'link': '/tournaments/rco-c-12-27-2024', 'location': 'RICC', 'type': 'RCO', 'level': 'C-', 'cost': '6:00 PM', 'max_teams': '$100', 'confirmed': 'RIR TD', 'status': '4'}
# {'date': '12/27/24', 'name': 'RCO C 12/27/2024', 'link': '/tournaments/rco-c-12-27-20241', 'location': 'RICC', 'type': 'RCO', 'level': 'C', 'cost': '6:00 PM', 'max_teams': '$100', 'confirmed': 'RIR TD', 'status': '8'}
# {'date': '12/27/24', 'name': 'RCO C+ 12/27/2024', 'link': '/tournaments/rco-c-12-27-20242', 'location': 'RICC', 'type': 'RCO', 'level': 'C+', 'cost': '6:00 PM', 'max_teams': '$100', 'confirmed': 'RIR TD', 'status': '24'}
# {'date': '12/27/24', 'name': 'RCO B- 12/27/2024', 'link': '/tournaments/rco-b-12-27-2024', 'location': 'RICC', 'type': 'RCO', 'level': 'B-', 'cost': '6:00 PM', 'max_teams': '$100', 'confirmed': 'RIR TD', 'status': '4'}
# {'date': '12/27/24', 'name': 'RCO B 12/27/2024', 'link': '/tournaments/rco-b-12-27-20241', 'location': 'RICC', 'type': 'RCO', 'level': 'B', 'cost': '6:00 PM', 'max_teams': '$100', 'confirmed': 'RIR TD', 'status': '4'}
# {'date': '12/27/24', 'name': 'RCO OPEN 12/27/2024', 'link': '/tournaments/rco-open-12-27-2024', 'location': 'RICC', 'type': 'RCO', 'level': '', 'cost': '6:00 PM', 'max_teams': '$100', 'confirmed': 'RIR TD', 'status': '4'}
# {'date': '12/28/24', 'name': 'RCO C- 12/28/2024', 'link': '/tournaments/rco-c-12-28-2024', 'location': 'RICC', 'type': 'RCO', 'level': 'C-', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'RIR TD', 'status': '5'}
# {'date': '12/28/24', 'name': 'RCO C 12/28/2024', 'link': '/tournaments/rco-c-12-28-20241', 'location': 'RICC', 'type': 'RCO', 'level': 'C', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'RIR TD', 'status': '20'}
# {'date': '12/28/24', 'name': 'RCO C+ 12/28/2024', 'link': '/tournaments/rco-c-12-28-20242', 'location': 'RICC', 'type': 'RCO', 'level': 'C+', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'RIR TD', 'status': '25'}
# {'date': '12/28/24', 'name': 'RCO B- 12/28/2024', 'link': '/tournaments/rco-b-12-28-2024', 'location': 'RICC', 'type': 'RCO', 'level': 'B-', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'RIR TD', 'status': '25'}
# {'date': '12/28/24', 'name': 'RCO B 12/28/2024', 'link': '/tournaments/rco-b-12-28-20241', 'location': 'RICC', 'type': 'RCO', 'level': 'B', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'RIR TD', 'status': '10'}
# {'date': '12/28/24', 'name': 'RCO B/OPEN 12/28/2024', 'link': '/tournaments/rco-open-12-28-2024', 'location': 'RICC', 'type': 'RCO', 'level': 'BB/A', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'RIR TD', 'status': '8'}
# {'date': '12/28/24', 'name': 'RCO C 12/28/2024', 'link': '/tournaments/rco-c--12-28-2024', 'location': 'RICC', 'type': 'RCO', 'level': 'C', 'cost': '8:30 AM', 'max_teams': '$35pp', 'confirmed': 'Scramble TD', 'status': '30'}
# {'date': '12/29/24', 'name': 'M OPEN 12/29/2024', 'link': '/tournaments/m-open-12-29-2024', 'location': 'RICC', 'type': 'M', 'level': 'OPEN', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'RIR TD', 'status': '10'}
# {'date': '12/29/24', 'name': 'W OPEN 12/29/2024', 'link': '/tournaments/w-open-12-29-2024', 'location': 'RICC', 'type': 'W', 'level': 'OPEN', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'RIR TD', 'status': '5'}
# {'date': '12/29/24', 'name': 'W B- 12/29/2024', 'link': '/tournaments/w-b-12-29-2024', 'location': 'RICC', 'type': 'W', 'level': 'B-', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'RIR TD', 'status': '10'}
# {'date': '12/29/24', 'name': 'M B- 12/29/2024', 'link': '/tournaments/m-b-12-29-2024', 'location': 'RICC', 'type': 'M', 'level': 'B-', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'RIR TD', 'status': '15'}
# {'date': '12/29/24', 'name': 'W C+ 12/29/2024', 'link': '/tournaments/w-c-12-29-2024', 'location': 'RICC', 'type': 'W', 'level': 'C+', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'RIR TD', 'status': '10'}
# {'date': '12/29/24', 'name': 'M C+ 12/29/2024', 'link': '/tournaments/m-c-12-29-2024', 'location': 'RICC', 'type': 'M', 'level': 'C+', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'RIR TD', 'status': '15'}
# {'date': '12/29/24', 'name': 'W C 12/29/2024', 'link': '/tournaments/w-c-12-29-20241', 'location': 'RICC', 'type': 'W', 'level': 'C', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'RIR TD', 'status': '5'}
# {'date': '12/29/24', 'name': 'M C 12/29/2024', 'link': '/tournaments/m-c-12-29-20241', 'location': 'RICC', 'type': 'M', 'level': 'C', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'RIR TD', 'status': '15'}
# {'date': '12/29/24', 'name': 'W C- 12/29/2024', 'link': '/tournaments/w-c-12-29-20242', 'location': 'RICC', 'type': 'W', 'level': 'C-', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'RIR TD', 'status': '5'}
# {'date': '12/29/24', 'name': 'M C- 12/29/2024', 'link': '/tournaments/m-c-12-29-20242', 'location': 'RICC', 'type': 'M', 'level': 'C-', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'RIR TD', 'status': '5'}
# {'date': '12/31/24', 'name': 'RCO C 12/31/2024', 'link': '/tournaments/rco-c-12-31-2024', 'location': 'SLAM', 'type': 'RCO', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '12/31/24', 'name': 'RCO B- 12/31/2024', 'link': '/tournaments/rco-b-12-31-2024', 'location': 'SLAM', 'type': 'RCO', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '01/01/25', 'name': 'RCO C+ 1/01/2025', 'link': '/tournaments/rco-c-1-01-2025', 'location': 'SLAM', 'type': 'RCO', 'level': 'C+', 'cost': '11:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '10'}
# {'date': '01/04/25', 'name': 'W C 1/04/2025', 'link': '/tournaments/w-c-1-04-2025', 'location': 'TAU', 'type': 'W', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$195', 'confirmed': 'Yankee TD', 'status': '5'}
# {'date': '01/04/25', 'name': 'M C 1/04/2025', 'link': '/tournaments/m-c-1-04-2025', 'location': 'TAU', 'type': 'M', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$195', 'confirmed': 'Yankee TD', 'status': '5'}
# {'date': '01/04/25', 'name': 'W B(Flat) 1/04/2025', 'link': '/tournaments/w-bflat-1-04-2025', 'location': 'NECC', 'type': 'W', 'level': 'B', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '01/04/25', 'name': 'RCO C+ 1/04/2025', 'link': '/tournaments/rco-c-1-04-2025', 'location': 'BRU', 'type': 'RCO', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$210', 'confirmed': 'Mark Robarts', 'status': '15'}
# {'date': '01/04/25', 'name': 'M B- 1/04/2025', 'link': '/tournaments/m-b-1-04-2025', 'location': 'NECC', 'type': 'M', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '01/05/25', 'name': 'M B- 1/05/2025', 'link': '/tournaments/m-b-1-05-2025', 'location': 'KCC', 'type': 'M', 'level': 'B-', 'cost': '8:30 AM', 'max_teams': '$200', 'confirmed': 'Zack Dalton', 'status': '5'}
# {'date': '01/05/25', 'name': 'RCO C 1/05/2025', 'link': '/tournaments/rco-c-1-05-2025', 'location': 'STW', 'type': 'RCO', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$198', 'confirmed': 'Michelle Grambley', 'status': '10'}
# {'date': '01/05/25', 'name': 'RCO B- 1/05/2025', 'link': '/tournaments/rco-b-1-05-2025', 'location': 'FIT', 'type': 'RCO', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '10'}
# {'date': '01/05/25', 'name': 'RCO B 1/05/2025', 'link': '/tournaments/rco-b-1-05-20251', 'location': 'FIT', 'type': 'RCO', 'level': 'B', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '01/05/25', 'name': 'M C(Flat) 1/05/2025', 'link': '/tournaments/m-c-1-05-2025', 'location': 'NECC', 'type': 'M', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '01/05/25', 'name': 'W C- 1/05/2025', 'link': '/tournaments/w-c-1-05-2025', 'location': 'NECC', 'type': 'W', 'level': 'C-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '01/05/25', 'name': 'W C+ 1/05/2025', 'link': '/tournaments/w-c-1-05-20251', 'location': 'KCC', 'type': 'W', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'Zack Dalton', 'status': '4'}
# {'date': '01/05/25', 'name': 'M C+ 1/05/2025', 'link': '/tournaments/m-c-1-05-20251', 'location': 'BRU', 'type': 'M', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$210', 'confirmed': 'Mark Robarts', 'status': '15'}
# {'date': '01/11/25', 'name': 'RCO B(Flat) 1/11/2025', 'link': '/tournaments/rco-bflat-1-11-2025', 'location': 'GOF', 'type': 'RCO', 'level': 'B', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '01/11/25', 'name': 'RCO C(Flat) 1/11/2025', 'link': '/tournaments/rco-cflat-1-11-2025', 'location': 'NECC', 'type': 'RCO', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '10'}
# {'date': '01/11/25', 'name': 'RCO C- 1/11/2025', 'link': '/tournaments/rco-c-1-11-2025', 'location': 'GOF', 'type': 'RCO', 'level': 'C-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '01/11/25', 'name': 'M C+ 1/11/2025', 'link': '/tournaments/m-c-1-11-2025', 'location': 'BRU', 'type': 'M', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$210', 'confirmed': 'Mark Robarts', 'status': '15'}
# {'date': '01/11/25', 'name': 'M C 1/11/2025', 'link': '/tournaments/m-c--1-11-2025', 'location': 'CTSC', 'type': 'M', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$37pp', 'confirmed': 'Scramble TD', 'status': '30'}
# {'date': '01/11/25', 'name': 'W C 1/11/2025', 'link': '/tournaments/w-c--1-11-2025', 'location': 'CTSC', 'type': 'W', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$37pp', 'confirmed': 'Scramble TD', 'status': '30'}
# {'date': '01/11/25', 'name': 'W C+ 1/11/2025', 'link': '/tournaments/w-c-1-11-2025', 'location': 'BRU', 'type': 'W', 'level': 'C+', 'cost': '11:00 AM', 'max_teams': '$210', 'confirmed': 'Mark Robarts', 'status': '5'}
# {'date': '01/12/25', 'name': 'RCO C+ 1/12/2025', 'link': '/tournaments/rco-c-1-12-2025', 'location': 'TAU', 'type': 'RCO', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$195', 'confirmed': 'Yankee TD', 'status': '10'}
# {'date': '01/12/25', 'name': 'RCO C 1/12/2025', 'link': '/tournaments/rco-c-1-12-20251', 'location': 'TAU', 'type': 'RCO', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$35pp', 'confirmed': 'Scramble TD', 'status': '60'}
# {'date': '01/12/25', 'name': 'W B(Flat) 1/12/2025', 'link': '/tournaments/w-bflat-1-12-2025', 'location': 'NECC', 'type': 'W', 'level': 'B', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '01/12/25', 'name': 'M B- 1/12/2025', 'link': '/tournaments/m-b-1-12-2025', 'location': 'NECC', 'type': 'M', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '01/12/25', 'name': 'M C+ 1/12/2025', 'link': '/tournaments/m-c-1-12-2025', 'location': 'GOF', 'type': 'M', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '10'}
# {'date': '01/18/25', 'name': 'M B- 1/18/2025', 'link': '/tournaments/m-b-1-18-2025', 'location': 'NECC', 'type': 'M', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '01/18/25', 'name': 'RCO B-(Flat) 1/18/2025', 'link': '/tournaments/rco-b-flat-1-18-2025', 'location': 'SMCC', 'type': 'RCO', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'Zack Dalton', 'status': '5'}
# {'date': '01/18/25', 'name': 'W B(Flat) 1/18/2025', 'link': '/tournaments/w-bflat-1-18-2025', 'location': 'NECC', 'type': 'W', 'level': 'B', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '01/18/25', 'name': 'RCO C 1/18/2025', 'link': '/tournaments/rco-c-1-18-2025', 'location': 'SMCC', 'type': 'RCO', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'Zack Dalton', 'status': '5'}
# {'date': '01/18/25', 'name': 'RCO C+ 1/18/2025', 'link': '/tournaments/rco-c-1-18-20251', 'location': 'STW', 'type': 'RCO', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$198', 'confirmed': 'Michelle Grambley', 'status': '10'}
# {'date': '01/18/25', 'name': 'W C 1/18/2025', 'link': '/tournaments/w-c-1-18-2025', 'location': 'CTSC', 'type': 'W', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$222', 'confirmed': 'Jimmy Guo', 'status': '5'}
# {'date': '01/18/25', 'name': 'M C 1/18/2025', 'link': '/tournaments/m-c-1-18-2025', 'location': 'CTSC', 'type': 'M', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$222', 'confirmed': 'Jimmy Guo', 'status': '5'}
# {'date': '01/19/25', 'name': 'M B 1/19/2025', 'link': '/tournaments/m-b-1-19-2025', 'location': 'NECC', 'type': 'M', 'level': 'B', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '10'}
# {'date': '01/19/25', 'name': 'RCO B- 1/19/2025', 'link': '/tournaments/rco-b-1-19-2025', 'location': 'MWK', 'type': 'RCO', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$210', 'confirmed': 'Mark Robarts', 'status': '10'}
# {'date': '01/19/25', 'name': 'RCO C 1/19/2025', 'link': '/tournaments/rco-c-1-19-2025', 'location': 'MWK', 'type': 'RCO', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$210', 'confirmed': 'Mark Robarts', 'status': '10'}
# {'date': '01/19/25', 'name': 'M C(Flat) 1/19/2025', 'link': '/tournaments/m-cflat-1-19-2025', 'location': 'MWK', 'type': 'M', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$210', 'confirmed': 'Mark Robarts', 'status': '10'}
# {'date': '01/19/25', 'name': 'W C(Flat) 1/19/2025', 'link': '/tournaments/w-cflat-1-19-2025', 'location': 'MWK', 'type': 'W', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$210', 'confirmed': 'Mark Robarts', 'status': '10'}
# {'date': '01/19/25', 'name': 'M C+ 1/19/2025', 'link': '/tournaments/m-c-1-19-2025', 'location': 'MWK', 'type': 'M', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$210', 'confirmed': 'Mark Robarts', 'status': '10'}
# {'date': '01/19/25', 'name': 'W C+ 1/19/2025', 'link': '/tournaments/w-c-1-19-2025', 'location': 'MWK', 'type': 'W', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$210', 'confirmed': 'Mark Robarts', 'status': '10'}
# {'date': '01/20/25', 'name': 'RCO B- 1/20/2025', 'link': '/tournaments/rco-b-1-20-2025', 'location': 'NECC', 'type': 'RCO', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '01/20/25', 'name': 'RCO C 1/20/2025', 'link': '/tournaments/rco-c-1-20-2025', 'location': 'NECC', 'type': 'RCO', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '01/25/25', 'name': 'RCO C 1/25/2025', 'link': '/tournaments/rco-c-1-25-2025', 'location': 'TAU', 'type': 'RCO', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'Yankee TD', 'status': '5'}
# {'date': '01/25/25', 'name': 'RCO C+ 1/25/2025', 'link': '/tournaments/rco-c1-25-2025', 'location': 'TAU', 'type': 'RCO', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'Yankee TD', 'status': '5'}
# {'date': '01/26/25', 'name': 'M B- 1/26/2025', 'link': '/tournaments/m-b-1-26-2025', 'location': 'NECC', 'type': 'M', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '01/26/25', 'name': 'W B- 1/26/2025', 'link': '/tournaments/w-b-1-26-2025', 'location': 'NECC', 'type': 'W', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '01/26/25', 'name': 'RCO B- 1/26/2025', 'link': '/tournaments/rco-b-1-26-2025', 'location': 'CLB', 'type': 'RCO', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$180', 'confirmed': 'MSVBA TD', 'status': '5'}
# {'date': '01/26/25', 'name': 'M C 1/26/2025', 'link': '/tournaments/m-c-1-26-2025', 'location': 'CLB', 'type': 'M', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$180', 'confirmed': 'MSVBA TD', 'status': '5'}
# {'date': '01/26/25', 'name': 'W C 1/26/2025', 'link': '/tournaments/w-c-1-26-2025', 'location': 'CLB', 'type': 'W', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$180', 'confirmed': 'MSVBA TD', 'status': '5'}
# {'date': '02/01/25', 'name': 'M B(Flat) 2/01/2025', 'link': '/tournaments/m-bflat-2-01-2025', 'location': 'NECC', 'type': 'M', 'level': 'B', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '10'}
# {'date': '02/01/25', 'name': 'M C 2/01/2025', 'link': '/tournaments/m-c-2-01-2025', 'location': 'MWK', 'type': 'M', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$210', 'confirmed': 'Mark Robarts', 'status': '15'}
# {'date': '02/01/25', 'name': 'W C 2/01/2025', 'link': '/tournaments/w-c-2-01-2025', 'location': 'MWK', 'type': 'W', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$210', 'confirmed': 'Mark Robarts', 'status': '10'}
# {'date': '02/01/25', 'name': 'RCO C- 2/01/2025', 'link': '/tournaments/rco-c-2-01-2025', 'location': 'MWK', 'type': 'RCO', 'level': 'C-', 'cost': '9:00 AM', 'max_teams': '$210', 'confirmed': 'Mark Robarts', 'status': '10'}
# {'date': '02/01/25', 'name': 'M C+ 2/01/2025', 'link': '/tournaments/m-c-2-01-20251', 'location': 'MWK', 'type': 'M', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$210', 'confirmed': 'Mark Robarts', 'status': '10'}
# {'date': '02/01/25', 'name': 'W C+ 2/01/2025', 'link': '/tournaments/w-c-2-01-20251', 'location': 'MWK', 'type': 'W', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$210', 'confirmed': 'Mark Robarts', 'status': '10'}
# {'date': '02/02/25', 'name': 'RCO C+ 2/02/2025', 'link': '/tournaments/rco-c-2-02-20251', 'location': 'KCC', 'type': 'RCO', 'level': 'C+', 'cost': '8:30 AM', 'max_teams': '$200', 'confirmed': 'Zack Dalton', 'status': '5'}
# {'date': '02/02/25', 'name': 'W B(Flat) 2/02/2025', 'link': '/tournaments/w-bflat-2-02-2025', 'location': 'NECC', 'type': 'W', 'level': 'B', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '02/02/25', 'name': 'RCO C 2/02/2025', 'link': '/tournaments/rco-c-2-02-2025', 'location': 'STW', 'type': 'RCO', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$198', 'confirmed': 'Michelle Grambley', 'status': '10'}
# {'date': '02/02/25', 'name': 'W C- 2/02/2025', 'link': '/tournaments/w-c-2-02-2025', 'location': 'NECC', 'type': 'W', 'level': 'C-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '02/08/25', 'name': 'M B- 2/08/2025', 'link': '/tournaments/m-b-2-08-2025', 'location': 'STW', 'type': 'M', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$198', 'confirmed': 'Michelle Grambley', 'status': '10'}
# {'date': '02/08/25', 'name': 'RCO C+ 2/08/2025', 'link': '/tournaments/rco-c-2-08-2025', 'location': 'TUH', 'type': 'RCO', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$205', 'confirmed': 'Kris Jeffers', 'status': '10'}
# {'date': '02/08/25', 'name': 'RCO C+(Flat) 2/08/2025', 'link': '/tournaments/rco-cflat-2-08-2025', 'location': 'CTSC', 'type': 'RCO', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$222', 'confirmed': 'Jimmy Guo', 'status': '10'}
# {'date': '02/09/25', 'name': 'M B- 2/09/2025', 'link': '/tournaments/m-b-2-09-2025', 'location': 'NECC', 'type': 'M', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '02/09/25', 'name': 'W B(Flat) 2/09/2025', 'link': '/tournaments/w-bflat-2-09-2025', 'location': 'NECC', 'type': 'W', 'level': 'B', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '02/09/25', 'name': 'RCO C+ 2/09/2025', 'link': '/tournaments/rco-c-2-09-2025', 'location': 'STW', 'type': 'RCO', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$198', 'confirmed': 'Michelle Grambley', 'status': '10'}
# {'date': '02/09/25', 'name': 'RCO C+ 2/09/2025', 'link': '/tournaments/rco-c--2-09-2025', 'location': 'SMCC', 'type': 'RCO', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'Zack Dalton', 'status': '8'}
# {'date': '02/15/25', 'name': 'M C+ 2/15/2025', 'link': '/tournaments/m-c-2-15-2025', 'location': 'BRU', 'type': 'M', 'level': 'C+', 'cost': '8:00 AM', 'max_teams': '$210', 'confirmed': 'Mark Robarts', 'status': '10'}
# {'date': '02/15/25', 'name': 'W C+ 2/15/2025', 'link': '/tournaments/w-c-2-15-2025', 'location': 'BRU', 'type': 'W', 'level': 'C+', 'cost': '8:00 AM', 'max_teams': '$210', 'confirmed': 'Mark Robarts', 'status': '10'}
# {'date': '02/15/25', 'name': 'RCO B- 2/15/2025', 'link': '/tournaments/rco-b-2-15-2025', 'location': 'NECC', 'type': 'RCO', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '10'}
# {'date': '02/15/25', 'name': 'RCO C 2/15/2025', 'link': '/tournaments/rco-c-2-15-2025', 'location': 'TUH', 'type': 'RCO', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$205', 'confirmed': 'Kris Jeffers', 'status': '10'}
# {'date': '02/16/25', 'name': 'W C 2/16/2025', 'link': '/tournaments/w-c-2-16-2025', 'location': 'TAU', 'type': 'W', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$35pp', 'confirmed': 'Scramble TD', 'status': '30'}
# {'date': '02/16/25', 'name': 'M C 2/16/2025', 'link': '/tournaments/m-c-2-16-2025', 'location': 'TAU', 'type': 'M', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$35pp', 'confirmed': 'Scramble TD', 'status': '30'}
# {'date': '02/16/25', 'name': 'W B- 2/16/2025', 'link': '/tournaments/w-b-2-16-2025', 'location': 'TAU', 'type': 'W', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'Yankee TD', 'status': '10'}
# {'date': '02/16/25', 'name': 'M B- 2/16/2025', 'link': '/tournaments/m-b-2-16-2025', 'location': 'BRU', 'type': 'M', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$210', 'confirmed': 'Mark Robarts', 'status': '15'}
# {'date': '02/22/25', 'name': 'M B- 2/22/2025', 'link': '/tournaments/m-b-2-22-2025', 'location': 'TUH', 'type': 'M', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$205', 'confirmed': 'Kris Jeffers', 'status': '10'}
# {'date': '02/22/25', 'name': 'W B- 2/22/2025', 'link': '/tournaments/w-b-2-22-2025', 'location': 'TUH', 'type': 'W', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$205', 'confirmed': 'Kris Jeffers', 'status': '10'}
# {'date': '02/22/25', 'name': 'M B-(Flat) 2/22/2025', 'link': '/tournaments/m-b-flat-2-22-2025', 'location': 'LEWA', 'type': 'M', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'Zack Dalton', 'status': '5'}
# {'date': '02/22/25', 'name': 'W B-(Flat) 2/22/2025', 'link': '/tournaments/w-b-flat-2-22-2025', 'location': 'LEWA', 'type': 'W', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'Zack Dalton', 'status': '5'}
# {'date': '02/22/25', 'name': 'RCO C 2/22/2025', 'link': '/tournaments/rco-c-2-22-2025', 'location': 'TUH', 'type': 'RCO', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$205', 'confirmed': 'Kris Jeffers', 'status': '10'}
# {'date': '02/22/25', 'name': 'M C 2/22/2025', 'link': '/tournaments/m-c-2-22-2025', 'location': 'LEWA', 'type': 'M', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'Zack Dalton', 'status': '5'}
# {'date': '02/22/25', 'name': 'M C- 2/22/2025', 'link': '/tournaments/m-c-2-22-20251', 'location': 'NECC', 'type': 'M', 'level': 'C-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '02/22/25', 'name': 'W C- 2/22/2025', 'link': '/tournaments/w-c-2-22-2025', 'location': 'NECC', 'type': 'W', 'level': 'C-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '02/22/25', 'name': 'M C+ 2/22/2025', 'link': '/tournaments/m-c-2-22-20252', 'location': 'TUH', 'type': 'M', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$205', 'confirmed': 'Kris Jeffers', 'status': '10'}
# {'date': '02/22/25', 'name': 'W C+\xa0 2/22/2025', 'link': '/tournaments/w-c-2-22-20251', 'location': 'TUH', 'type': 'W', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$205', 'confirmed': 'Kris Jeffers', 'status': '10'}
# {'date': '02/23/25', 'name': 'RCO B- 2/23/2025', 'link': '/tournaments/rco-b-2-23-2025', 'location': 'BRU', 'type': 'RCO', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$210', 'confirmed': 'Mark Robarts', 'status': '15'}
# {'date': '02/23/25', 'name': 'RCO C 2/23/2025', 'link': '/tournaments/rco-c-2-23-2025', 'location': 'STW', 'type': 'RCO', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$198', 'confirmed': 'Michelle Grambley', 'status': '10'}
# {'date': '02/23/25', 'name': 'RCO C- 2/23/2025', 'link': '/tournaments/rco-c-2-23-20251', 'location': 'NECC', 'type': 'RCO', 'level': 'C-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '02/23/25', 'name': 'M C+ 2/23/2025', 'link': '/tournaments/m-c-2-23-2025', 'location': 'NECC', 'type': 'M', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '03/01/25', 'name': 'RCO B- 3/01/2025', 'link': '/tournaments/rco-b-3-01-2025', 'location': 'TUH', 'type': 'RCO', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$205', 'confirmed': 'Kris Jeffers', 'status': '10'}
# {'date': '03/01/25', 'name': 'RCO C 3/01/2025', 'link': '/tournaments/rco-c-3-01-2025', 'location': 'TUH', 'type': 'RCO', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$205', 'confirmed': 'Kris Jeffers', 'status': '10'}
# {'date': '03/01/25', 'name': 'RCO C+ 3/01/2025', 'link': '/tournaments/rco-c-3-01-20251', 'location': 'NECC', 'type': 'RCO', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '10'}
# {'date': '03/01/25', 'name': 'M C+ 3/01/2025', 'link': '/tournaments/m-c-3-01-2025', 'location': 'STW', 'type': 'M', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$198', 'confirmed': 'Michelle Grambley', 'status': '10'}
# {'date': '03/01/25', 'name': 'M B-(Flat) 3/01/2025', 'link': '/tournaments/m-b-flat-3-01-2025', 'location': 'CTSC', 'type': 'M', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$222', 'confirmed': 'Jimmy Guo', 'status': '5'}
# {'date': '03/01/25', 'name': 'W B-(Flat) 3/01/2025', 'link': '/tournaments/w-b-flat-3-01-2025', 'location': 'CTSC', 'type': 'W', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$222', 'confirmed': 'Jimmy Guo', 'status': '5'}
# {'date': '03/02/25', 'name': 'M B- 3/02/2025', 'link': '/tournaments/m-b-3-02-2025', 'location': 'KCC', 'type': 'M', 'level': 'B-', 'cost': '8:30 AM', 'max_teams': '$200', 'confirmed': 'Zack Dalton', 'status': '5'}
# {'date': '03/02/25', 'name': 'W B- 3/02/2025', 'link': '/tournaments/w-b-3-02-2025', 'location': 'STW', 'type': 'W', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$198', 'confirmed': 'Michelle Grambley', 'status': '10'}
# {'date': '03/02/25', 'name': 'W C- 3/02/2025', 'link': '/tournaments/w-c-3-02-2025', 'location': 'NECC', 'type': 'W', 'level': 'C-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '03/02/25', 'name': 'M C(Flat) 3/02/2025', 'link': '/tournaments/m-cflat-3-02-2025', 'location': 'NECC', 'type': 'M', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '03/02/25', 'name': 'M C+ 3/02/2025', 'link': '/tournaments/m-c-3-02-2025', 'location': 'TUH', 'type': 'M', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$205', 'confirmed': 'Kris Jeffers', 'status': '10'}
# {'date': '03/02/25', 'name': 'W C+ 3/02/2025', 'link': '/tournaments/w-c-3-02-20251', 'location': 'TUH', 'type': 'W', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$205', 'confirmed': 'Kris Jeffers', 'status': '10'}
# {'date': '03/08/25', 'name': 'M B(Flat) 3/08/2025', 'link': '/tournaments/m-bflat-3-08-2025', 'location': 'NECC', 'type': 'M', 'level': 'B', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '03/08/25', 'name': 'W B(Flat) 3/08/2025', 'link': '/tournaments/w-bflat-3-08-2025', 'location': 'NECC', 'type': 'W', 'level': 'B', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '03/08/25', 'name': 'RCO C 3/08/2025', 'link': '/tournaments/rco-c-3-08-2025', 'location': 'STW', 'type': 'RCO', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$198', 'confirmed': 'Michelle Grambley', 'status': '10'}
# {'date': '03/08/25', 'name': 'RCO C 3/08/2025', 'link': '/tournaments/RCO-c--3-08-2025', 'location': 'SMCC', 'type': 'RCO', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'Zack Dalton', 'status': '5'}
# {'date': '03/08/25', 'name': 'M C+(Flat) 3/08/2025', 'link': '/tournaments/m-cflat-3-08-2025', 'location': 'SMCC', 'type': 'M', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'Zack Dalton', 'status': '5'}
# {'date': '03/09/25', 'name': 'RCO B- 3/09/2025', 'link': '/tournaments/rco-b-3-09-2025', 'location': 'SJC', 'type': 'RCO', 'level': 'B-', 'cost': '8:30 AM', 'max_teams': '$180', 'confirmed': 'MSVBA TD', 'status': '5'}
# {'date': '03/09/25', 'name': 'W C+(Flat) 3/09/2025', 'link': '/tournaments/w-cflat-3-09-2025', 'location': 'SJC', 'type': 'W', 'level': 'C+', 'cost': '8:30 AM', 'max_teams': '$180', 'confirmed': 'MSVBA TD', 'status': '5'}
# {'date': '03/09/25', 'name': 'W C- 3/09/2025', 'link': '/tournaments/w-c-3-09-2025', 'location': 'NECC', 'type': 'W', 'level': 'C-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '03/09/25', 'name': 'W C+ 3/09/2025', 'link': '/tournaments/w-c-3-09-20251', 'location': 'NECC', 'type': 'W', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '03/09/25', 'name': 'M C+ 3/09/2025', 'link': '/tournaments/m-c-3-09-2025', 'location': 'STW', 'type': 'M', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$198', 'confirmed': 'Michelle Grambley', 'status': '10'}
# {'date': '03/15/25', 'name': 'M C 3/15/2025', 'link': '/tournaments/m-c-3-15-2025', 'location': 'SMCC', 'type': 'M', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$24pp', 'confirmed': 'Scramble TD', 'status': '30'}
# {'date': '03/15/25', 'name': 'RCO C+ 3/15/2025', 'link': '/tournaments/rco-c-3-15-2025', 'location': 'SMCC', 'type': 'RCO', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'Zack Dalton', 'status': '5'}
# {'date': '03/15/25', 'name': 'RCO B- 3/15/2025', 'link': '/tournaments/rco-b-3-15-2025', 'location': 'NECC', 'type': 'RCO', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '10'}
# {'date': '03/15/25', 'name': 'RCO C+ 3/15/2025', 'link': '/tournaments/rco-c--3-15-2025', 'location': 'STW', 'type': 'RCO', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$198', 'confirmed': 'Michelle Grambley', 'status': '10'}
# {'date': '03/16/25', 'name': 'RCO C 3/16/2025', 'link': '/tournaments/rco-c-3-16-2025', 'location': 'TAU', 'type': 'RCO', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$35pp', 'confirmed': 'Scramble TD', 'status': '60'}
# {'date': '03/16/25', 'name': 'M C+ 3/16/2025', 'link': '/tournaments/m-c-3-16-2025', 'location': 'TAU', 'type': 'M', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'Yankee TD', 'status': '10'}
# {'date': '03/16/25', 'name': 'M B- 3/16/2025', 'link': '/tournaments/m-b-3-16-2025', 'location': 'NECC', 'type': 'M', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '03/16/25', 'name': 'W B- 3/16/2025', 'link': '/tournaments/w-b-3-16-2025', 'location': 'NECC', 'type': 'W', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '03/16/25', 'name': 'W C+ 3/16/2025', 'link': '/tournaments/w-c-3-16-2025', 'location': 'MIT', 'type': 'W', 'level': 'C+', 'cost': '9:30 AM', 'max_teams': '$195', 'confirmed': 'Bridget Denzer', 'status': '10'}
# {'date': '03/22/25', 'name': 'M B- 3/22/2025', 'link': '/tournaments/m-b-3-22-2025', 'location': 'QHS', 'type': 'M', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$205', 'confirmed': 'Kevin Phu', 'status': '10'}
# {'date': '03/22/25', 'name': 'M C 3/22/2025', 'link': '/tournaments/m-c-3-22-2025', 'location': 'MHS', 'type': 'M', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$198', 'confirmed': 'Steven Simmons', 'status': '10'}
# {'date': '03/22/25', 'name': 'W C 3/22/2025', 'link': '/tournaments/w-c-3-22-2025', 'location': 'MHS', 'type': 'W', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$198', 'confirmed': 'Steven Simmons', 'status': '5'}
# {'date': '03/22/25', 'name': 'RCO C 3/22/2025', 'link': '/tournaments/rco-c-3-22-2025', 'location': 'SMCC', 'type': 'RCO', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'Zack Dalton', 'status': '5'}
# {'date': '03/22/25', 'name': 'M C+ 3/22/2025', 'link': '/tournaments/m-c-3-22-20251', 'location': 'NECC', 'type': 'M', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '10'}
# {'date': '03/22/25', 'name': 'W C+ 3/22/2025', 'link': '/tournaments/w-c-3-22-20251', 'location': 'QHS', 'type': 'W', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$205', 'confirmed': 'Kevin Phu', 'status': '5'}
# {'date': '03/22/25', 'name': 'RCO C+ 3/22/2025', 'link': '/tournaments/rco-c-3-22-20251', 'location': 'SMCC', 'type': 'RCO', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'Zack Dalton', 'status': '5'}
# {'date': '03/23/25', 'name': 'W B- 3/23/2025', 'link': '/tournaments/w-b-3-23-2025', 'location': 'NECC', 'type': 'W', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '03/23/25', 'name': 'RCO C 3/23/2025', 'link': '/tournaments/rco-c-3-23-2025', 'location': 'STW', 'type': 'RCO', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$198', 'confirmed': 'Michelle Grambley', 'status': '10'}
# {'date': '03/23/25', 'name': 'W C- 3/23/2025', 'link': '/tournaments/w-c-3-23-2025', 'location': 'NECC', 'type': 'W', 'level': 'C-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '03/29/25', 'name': 'M C+(Flat) 3/29/2025', 'link': '/tournaments/m-cflat-3-29-2025', 'location': 'SPCM', 'type': 'M', 'level': 'C+', 'cost': '8:30 AM', 'max_teams': '$180', 'confirmed': 'MSVBA TD', 'status': '4'}
# {'date': '03/29/25', 'name': 'W C+(Flat) 3/29/2025', 'link': '/tournaments/w-cflat-3-29-2025', 'location': 'SPCM', 'type': 'W', 'level': 'C+', 'cost': '8:30 AM', 'max_teams': '$180', 'confirmed': 'MSVBA TD', 'status': '4'}
# {'date': '03/29/25', 'name': 'RCO C 3/29/2025', 'link': '/tournaments/rco-c-3-29-2025', 'location': 'TAU', 'type': 'RCO', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'Yankee TD', 'status': '10'}
# {'date': '03/29/25', 'name': 'M C- 3/29/2025', 'link': '/tournaments/m-c-3-29-2025', 'location': 'TAU', 'type': 'M', 'level': 'C-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'Yankee TD', 'status': '5'}
# {'date': '03/29/25', 'name': 'W C- 3/29/2025', 'link': '/tournaments/w-c-3-29-2025', 'location': 'TAU', 'type': 'W', 'level': 'C-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'Yankee TD', 'status': '5'}
# {'date': '03/29/25', 'name': 'M B(Flat) 3/29/2025', 'link': '/tournaments/m-bflat-3-29-2025', 'location': 'NECC', 'type': 'M', 'level': 'B', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '03/29/25', 'name': 'W B(Flat) 3/29/2025', 'link': '/tournaments/w-bflat-3-29-2025', 'location': 'NECC', 'type': 'W', 'level': 'B', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '03/29/25', 'name': 'RCO C+ 3/29/2025', 'link': '/tournaments/rco-c-3-29-20251', 'location': 'QHS', 'type': 'RCO', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$205', 'confirmed': 'Kevin Phu', 'status': '15'}
# {'date': '03/30/25', 'name': 'M C+ 3/30/2025', 'link': '/tournaments/m-c-3-30-2025', 'location': 'NECC', 'type': 'M', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '10'}
# {'date': '03/30/25', 'name': 'W C+ 3/30/2025', 'link': '/tournaments/w-c-3-30-2025', 'location': 'STW', 'type': 'W', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$198', 'confirmed': 'Michelle Grambley', 'status': '10'}
# {'date': '04/05/25', 'name': 'M B- 4/05/2025', 'link': '/tournaments/m-b-4-05-2025', 'location': 'NECC', 'type': 'M', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '04/05/25', 'name': 'RCO B- 4/05/2025', 'link': '/tournaments/rco-b-4-05-2025', 'location': 'QHS', 'type': 'RCO', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$205', 'confirmed': 'Kevin Phu', 'status': '15'}
# {'date': '04/05/25', 'name': 'RCO B(Flat) 4/05/2025', 'link': '/tournaments/rco-bflat-4-05-2025', 'location': 'SMCC', 'type': 'RCO', 'level': 'B', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'Zack Dalton', 'status': '5'}
# {'date': '04/05/25', 'name': 'W C(Flat) 4/05/2025', 'link': '/tournaments/w-cflat-4-05-2025', 'location': 'NECC', 'type': 'W', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '10'}
# {'date': '04/05/25', 'name': 'W C+ 4/05/2025', 'link': '/tournaments/w-c-4-05-2025', 'location': 'STW', 'type': 'W', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$198', 'confirmed': 'Michelle Grambley', 'status': '10'}
# {'date': '04/05/25', 'name': 'M C+ 4/05/2025', 'link': '/tournaments/m-c-4-05-2025', 'location': 'MHS', 'type': 'M', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$198', 'confirmed': 'Steven Simmons', 'status': '15'}
# {'date': '04/05/25', 'name': 'RCO C+(Flat) 4/05/2025', 'link': '/tournaments/rco-cflat-4-05-2025', 'location': 'SMCC', 'type': 'RCO', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'Zack Dalton', 'status': '5'}
# {'date': '04/06/25', 'name': 'RCO B-(Flat) 4/06/2025', 'link': '/tournaments/rco-b-flat-4-06-2025', 'location': 'KCC', 'type': 'RCO', 'level': 'B-', 'cost': '8:30 AM', 'max_teams': '$200', 'confirmed': 'Zack Dalton', 'status': '5'}
# {'date': '04/06/25', 'name': 'M C 4/06/2025', 'link': '/tournaments/m-c-4-06-2025', 'location': 'STW', 'type': 'M', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$198', 'confirmed': 'Michelle Grambley', 'status': '10'}
# {'date': '04/06/25', 'name': 'RCO C(Flat) 4/06/2025', 'link': '/tournaments/rco-cflat-4-06-2025', 'location': 'NECC', 'type': 'RCO', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '10'}
# {'date': '04/06/25', 'name': 'RCO C+ 4/06/2025', 'link': '/tournaments/rco-c-4-06-2025', 'location': 'CFHS', 'type': 'RCO', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$198', 'confirmed': 'Steven Simmons', 'status': '10'}
# {'date': '04/12/25', 'name': 'RCO OPEN 4/12/2025', 'link': '/tournaments/rco-open-4-12-2025', 'location': 'BCEC', 'type': 'RCO', 'level': 'OPEN', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'Liberty TD', 'status': '10'}
# {'date': '04/12/25', 'name': 'RCO C+ 4/12/2025', 'link': '/tournaments/rco-c-4-12-2025', 'location': 'BCEC', 'type': 'RCO', 'level': 'C+', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'Liberty Challenge CHAMPS TD', 'status': '40'}
# {'date': '04/12/25', 'name': 'RCO C- 4/12/2025', 'link': '/tournaments/rco-c-4-12-20251', 'location': 'BCEC', 'type': 'RCO', 'level': 'C-', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'Liberty Challenge CHAMPS TD', 'status': '10'}
# {'date': '04/12/25', 'name': 'RCO C 4/12/2025', 'link': '/tournaments/rco-c-4-12-20252', 'location': 'BCEC', 'type': 'RCO', 'level': 'C', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'Liberty TD', 'status': '15'}
# {'date': '04/12/25', 'name': 'RCO B- 4/12/2025', 'link': '/tournaments/rco-b-4-12-2025', 'location': 'BCEC', 'type': 'RCO', 'level': 'B-', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'Liberty TD', 'status': '15'}
# {'date': '04/12/25', 'name': 'RCO B 4/12/2025', 'link': '/tournaments/rco-b-4-12-20251', 'location': 'BCEC', 'type': 'RCO', 'level': 'B', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'Liberty Challenge CHAMPS TD', 'status': '10'}
# {'date': '04/13/25', 'name': 'M OPEN 4/13/2025', 'link': '/tournaments/m-open-4-13-2025', 'location': 'BCEC', 'type': 'M', 'level': 'OPEN', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'Liberty TD', 'status': '5'}
# {'date': '04/13/25', 'name': 'W OPEN 4/13/2025', 'link': '/tournaments/w-open-4-13-2025', 'location': 'BCEC', 'type': 'W', 'level': 'OPEN', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'Liberty TD', 'status': '5'}
# {'date': '04/13/25', 'name': 'M C+ 4/13/2025', 'link': '/tournaments/m-c-4-13-2025', 'location': 'BCEC', 'type': 'M', 'level': 'C+', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'Liberty TD', 'status': '15'}
# {'date': '04/13/25', 'name': 'W C+ 4/13/2025', 'link': '/tournaments/w-c-4-13-2025', 'location': 'BCEC', 'type': 'W', 'level': 'C+', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'Liberty TD', 'status': '10'}
# {'date': '04/13/25', 'name': 'M C- 4/13/2025', 'link': '/tournaments/m-c-4-13-20251', 'location': 'BCEC', 'type': 'M', 'level': 'C-', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'Liberty TD', 'status': '10'}
# {'date': '04/13/25', 'name': 'W C- 4/13/2025', 'link': '/tournaments/w-c-4-13-20251', 'location': 'BCEC', 'type': 'W', 'level': 'C-', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'Liberty TD', 'status': '5'}
# {'date': '04/13/25', 'name': 'M C 4/13/2025', 'link': '/tournaments/m-c-4-13-20252', 'location': 'BCEC', 'type': 'M', 'level': 'C', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'Liberty TD', 'status': '15'}
# {'date': '04/13/25', 'name': 'W C 4/13/2025', 'link': '/tournaments/w-c-4-13-20252', 'location': 'BCEC', 'type': 'W', 'level': 'C', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'Liberty TD', 'status': '15'}
# {'date': '04/13/25', 'name': 'M B- 4/13/2025', 'link': '/tournaments/m-b-4-13-2025', 'location': 'BCEC', 'type': 'M', 'level': 'B-', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'Liberty TD', 'status': '15'}
# {'date': '04/13/25', 'name': 'W B- 4/13/2025', 'link': '/tournaments/w-b-4-13-2025', 'location': 'BCEC', 'type': 'W', 'level': 'B-', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'Liberty TD', 'status': '10'}
# {'date': '04/13/25', 'name': 'M B 4/13/2025', 'link': '/tournaments/m-b-4-13-20251', 'location': 'BCEC', 'type': 'M', 'level': 'B', 'cost': '8:00 AM', 'max_teams': '$250', 'confirmed': 'Liberty TD', 'status': '10'}
# {'date': '04/18/25', 'name': 'RCO B(Flat) 4/18/2025', 'link': '/tournaments/rco-bflat-4-18-2025', 'location': 'NECC', 'type': 'RCO', 'level': 'B', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '04/18/25', 'name': 'RCO C(Flat) 4/18/2025', 'link': '/tournaments/rco-cflat-4-18-2025', 'location': 'NECC', 'type': 'RCO', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '04/19/25', 'name': 'M B- 4/19/2025', 'link': '/tournaments/m-b-4-19-2025', 'location': 'BRU', 'type': 'M', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$210', 'confirmed': 'Mark Robarts', 'status': '10'}
# {'date': '04/19/25', 'name': 'M C 4/19/2025', 'link': '/tournaments/m-c-4-19-2025', 'location': 'BRU', 'type': 'M', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$210', 'confirmed': 'Mark Robarts', 'status': '10'}
# {'date': '04/19/25', 'name': 'M C+ 4/19/2025', 'link': '/tournaments/m-c-4-19-20251', 'location': 'NECC', 'type': 'M', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '10'}
# {'date': '04/19/25', 'name': 'RCO C+(Flat) 4/19/2025', 'link': '/tournaments/rco-cflat-4-19-2025', 'location': 'RHS', 'type': 'RCO', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$205', 'confirmed': 'Kevin Phu', 'status': '5'}
# {'date': '04/20/25', 'name': 'W B(Flat) 4/20/2025', 'link': '/tournaments/w-bflat-4-20-2025', 'location': 'BRU', 'type': 'W', 'level': 'B', 'cost': '9:00 AM', 'max_teams': '$210', 'confirmed': 'Mark Robarts', 'status': '10'}
# {'date': '04/20/25', 'name': 'RCO C 4/20/2025', 'link': '/tournaments/rco-c-4-20-2025', 'location': 'BRU', 'type': 'RCO', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$210', 'confirmed': 'Mark Robarts', 'status': '10'}
# {'date': '04/20/25', 'name': 'W C(Flat) 4/20/2025', 'link': '/tournaments/w-cflat-4-20-2025', 'location': 'SLAM', 'type': 'W', 'level': 'C', 'cost': '10:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '04/20/25', 'name': 'RCO C+ 4/20/2025', 'link': '/tournaments/rco-c-4-20-20251', 'location': 'SLAM', 'type': 'RCO', 'level': 'C+', 'cost': '10:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '04/26/25', 'name': 'W C 4/26/2025', 'link': '/tournaments/w-c-4-26-2025', 'location': 'TAU', 'type': 'W', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'Yankee TD', 'status': '5'}
# {'date': '04/26/25', 'name': 'RCO C+ 4/26/2025', 'link': '/tournaments/rco-c-4-26-2025', 'location': 'TAU', 'type': 'RCO', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'Yankee TD', 'status': '15'}
# {'date': '04/26/25', 'name': 'RCO B- 4/26/2025', 'link': '/tournaments/rco-b-4-26-2025', 'location': 'NECC', 'type': 'RCO', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '10'}
# {'date': '04/26/25', 'name': 'M C 4/26/2025', 'link': '/tournaments/m-c-4-26-2025', 'location': 'STW', 'type': 'M', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$198', 'confirmed': 'Michelle Grambley', 'status': '10'}
# {'date': '04/27/25', 'name': 'M B- 4/27/2025', 'link': '/tournaments/m-b-4-27-2025', 'location': 'NECC', 'type': 'M', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '04/27/25', 'name': 'W B- 4/27/2025', 'link': '/tournaments/w-b-4-27-2025', 'location': 'NECC', 'type': 'W', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '5'}
# {'date': '04/27/25', 'name': 'M C+ 4/27/2025', 'link': '/tournaments/m-c-4-27-2025', 'location': 'STW', 'type': 'M', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$198', 'confirmed': 'Michelle Grambley', 'status': '10'}
# {'date': '05/03/25', 'name': 'RCO B- 5/03/2025', 'link': '/tournaments/rco-b-5-03-2025', 'location': 'TAU', 'type': 'RCO', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$215', 'confirmed': 'Yankee TD', 'status': '25'}
# {'date': '05/03/25', 'name': 'M C 5/03/2025', 'link': '/tournaments/m-c-5-03-2025', 'location': 'TAU', 'type': 'M', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$215', 'confirmed': 'Yankee TD', 'status': '15'}
# {'date': '05/04/25', 'name': 'M A/AA 5/04/2025', 'link': '/tournaments/m-a-aa-5-04-2025', 'location': 'TAU', 'type': 'M', 'level': 'A/AA', 'cost': '9:00 AM', 'max_teams': '$215', 'confirmed': 'Yankee TD', 'status': '5'}
# {'date': '05/04/25', 'name': 'W BB/A/AA 5/04/2025', 'link': '/tournaments/w-bb-a-aa-5-04-2025', 'location': 'TAU', 'type': 'W', 'level': 'BB/A/AA', 'cost': '9:00 AM', 'max_teams': '$215', 'confirmed': 'Yankee TD', 'status': '10'}
# {'date': '05/04/25', 'name': 'RCO C 5/04/2025', 'link': '/tournaments/rco-c-5-04-2025', 'location': 'TAU', 'type': 'RCO', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$215', 'confirmed': 'Yankee TD', 'status': '25'}
# {'date': '05/10/25', 'name': 'M B- 5/10/2025', 'link': '/tournaments/m-b-5-10-2025', 'location': 'TAU', 'type': 'M', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$215', 'confirmed': 'Yankee TD', 'status': '20'}
# {'date': '05/10/25', 'name': 'W B- 5/10/2025', 'link': '/tournaments/w-b-5-10-2025', 'location': 'TAU', 'type': 'W', 'level': 'B-', 'cost': '9:00 AM', 'max_teams': '$215', 'confirmed': 'Yankee TD', 'status': '10'}
# {'date': '05/10/25', 'name': 'M C- 5/10/2025', 'link': '/tournaments/m-c-5-10-2025', 'location': 'TAU', 'type': 'M', 'level': 'C-', 'cost': '9:00 AM', 'max_teams': '$215', 'confirmed': 'Yankee TD', 'status': '5'}
# {'date': '05/10/25', 'name': 'W C- 5/10/2025', 'link': '/tournaments/w-c-5-10-2025', 'location': 'TAU', 'type': 'W', 'level': 'C-', 'cost': '9:00 AM', 'max_teams': '$215', 'confirmed': 'Yankee TD', 'status': '5'}
# {'date': '05/11/25', 'name': 'M C+ 5/11/2025', 'link': '/tournaments/m-c-5-11-2025', 'location': 'TAU', 'type': 'M', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$215', 'confirmed': 'Yankee TD', 'status': '25'}
# {'date': '05/11/25', 'name': 'W C+ 5/11/2025', 'link': '/tournaments/w-c-5-11-2025', 'location': 'TAU', 'type': 'W', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$215', 'confirmed': 'Yankee TD', 'status': '10'}
# {'date': '05/17/25', 'name': 'M B 5/17/2025', 'link': '/tournaments/m-b-5-17-2025', 'location': 'TAU', 'type': 'M', 'level': 'B', 'cost': '9:00 AM', 'max_teams': '$215', 'confirmed': 'Yankee TD', 'status': '10'}
# {'date': '05/17/25', 'name': 'W C 5/17/2025', 'link': '/tournaments/w-c-5-17-2025', 'location': 'TAU', 'type': 'W', 'level': 'C', 'cost': '9:00 AM', 'max_teams': '$215', 'confirmed': 'Yankee TD', 'status': '10'}
# {'date': '05/17/25', 'name': 'CR C+ 5/17/2025', 'link': '/tournaments/cr-c-5-17-2025', 'location': 'TAU', 'type': 'CR', 'level': 'C+', 'cost': '9:00 AM', 'max_teams': '$215', 'confirmed': 'Yankee TD', 'status': '8'}
# {'date': '05/18/25', 'name': 'RCO C+ 5/18/2025', 'link': '/tournaments/rco-c-5-18-2025', 'location': 'SLAM', 'type': 'RCO', 'level': 'C+', 'cost': '10:00 AM', 'max_teams': '$200', 'confirmed': 'John Kubilis', 'status': '10'}

# %% [markdown]
# # Explanation of the Code
# ## HTML Structure Parsing:
#
# table = soup.find("table", class_="tournamentList"):
# Finds the main tournament table using its class attribute.
# for row in table.find("tbody").find_all("tr"):
# Loops through each row in the table body (<tbody>).
# Extracting Data:
#
# Each <td> cell corresponds to a specific piece of information, such as date, name, location, etc.
# Use .find_next("td") repeatedly to navigate through sibling cells.
# Handling Links:
#
# Extract the tournament detail page link from the <a> tag within the "Name" column.
# Error Handling:
#
# If a row is incomplete or malformed, AttributeError is caught, and the scraper skips that row.
# Output:
#
# Data is returned as a list of dictionaries, where each dictionary contains the details for one tournament.
